# %%
import osmnx as ox
import geopandas as gpd

# %%
place_name = "Saint Louis, MO, USA"

# %%
area = ox.geocode_to_gdf(place_name)

# %%
area
# Out:
#                                             geometry  bbox_west  bbox_south  \
# 0  POLYGON ((-90.32065 38.5942, -90.31636 38.5848... -90.320652   38.531859
#
#    bbox_east  bbox_north   place_id  osm_type   osm_id        lat        lon  \
# 0 -90.164194   38.774302  311347094  relation  1180533  38.628028 -90.191015
#
#       class            type  place_rank  importance addresstype       name  \
# 0  boundary  administrative          12    0.707855        city  St. Louis
#
#                          display_name
# 0  St. Louis, Missouri, United States

# %%
type(area)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
area.plot()
# Out:
# <Axes: >
